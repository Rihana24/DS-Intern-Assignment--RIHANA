# %% [markdown]
# # Importing pandas and reading the CSV file

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#                  timestamp equipment_energy_consumption     lighting_energy  \
# 0      2016-01-11 17:00:00                         60.0  -77.78778596503064
# 1      2016-01-11 17:10:00                         60.0                30.0
# 2      2016-01-11 17:20:00                         50.0                30.0
# 3      2016-01-11 17:30:00                         50.0                40.0
# 4      2016-01-11 17:40:00                         60.0                40.0
# ...                    ...                          ...                 ...
# 16852  2016-10-03 20:10:00           1139.9856929495108                20.0
# 16853  2016-10-04 06:10:00                         50.0   86.00296632575207
# 16854  2016-11-03 00:50:00                         50.0                 0.0
# 16855  2016-11-04 13:20:00                         80.0                 0.0
# 16856  2016-12-01 15:50:00                         30.0                 0.0
#
# ...

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %%
df.head(2)
# Out:
#              timestamp equipment_energy_consumption     lighting_energy  \
# 0  2016-01-11 17:00:00                         60.0  -77.78778596503064
# 1  2016-01-11 17:10:00                         60.0                30.0
#
#    zone1_temperature     zone1_humidity zone2_temperature  zone2_humidity  \
# 0  33.74660933896648  47.59666666666671              19.2         44.7900
# 1              19.89  46.69333333333329              19.2         44.7225
#
#    zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# 0              19.79             NaN               19.0  ...
# 1              19.79           44.79               19.0  ...
#
#    zone9_temperature  zone9_humidity  outdoor_temperature  \
# 0          17.033333           45.53             6.600000
# 1          17.066667           45.56             6.483333
#
#    atmospheric_pressure  outdoor_humidity  wind_speed  visibility_index  \
# 0                 733.5              92.0    7.000000         63.000000
# ...

# %% [markdown]
# # Understanding the structure of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16857 entries, 0 to 16856
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   timestamp                     16857 non-null  object
#  1   equipment_energy_consumption  16013 non-null  object
#  2   lighting_energy               16048 non-null  object
#  3   zone1_temperature             15990 non-null  object
#  4   zone1_humidity                16056 non-null  object
#  5   zone2_temperature             16004 non-null  object
#  6   zone2_humidity                15990 non-null  float64
#  7   zone3_temperature             16055 non-null  float64
#  8   zone3_humidity                15979 non-null  float64
#  9   zone4_temperature             16041 non-null  float64
#  10  zone4_humidity                16076 non-null  float64
#  11  zone5_temperature             16019 non-null  float64
# ...

# %% [markdown]
# # Checking for the missing values in the dataset

# %%
df.isnull().sum()
# Out:
# timestamp                         0
# equipment_energy_consumption    844
# lighting_energy                 809
# zone1_temperature               867
# zone1_humidity                  801
# zone2_temperature               853
# zone2_humidity                  867
# zone3_temperature               802
# zone3_humidity                  878
# zone4_temperature               816
# zone4_humidity                  781
# zone5_temperature               838
# zone5_humidity                  801
# zone6_temperature               848
# zone6_humidity                  847
# zone7_temperature               794
# zone7_humidity                  805
# zone8_temperature               848
# zone8_humidity                  777
# zone9_temperature               773
# zone9_humidity                  888
# outdoor_temperature             806
# atmospheric_pressure            842
# outdoor_humidity                799
# wind_speed                      828
# visibility_index                815
# ...

# %% [markdown]
# # Checking the unique values of the all columns in this dataframe

# %%
for i in df.columns:
  print(i,":",df[i].nunique())
# Out:
# timestamp : 16769
# equipment_energy_consumption : 130
# lighting_energy : 20
# zone1_temperature : 433
# zone1_humidity : 2172
# zone2_temperature : 838
# zone2_humidity : 2166
# zone3_temperature : 862
# zone3_humidity : 1986
# zone4_temperature : 923
# zone4_humidity : 2445
# zone5_temperature : 1633
# zone5_humidity : 6278
# zone6_temperature : 3144
# zone6_humidity : 8359
# zone7_temperature : 1427
# zone7_humidity : 4931
# zone8_temperature : 1672
# zone8_humidity : 5382
# zone9_temperature : 514
# zone9_humidity : 2387
# outdoor_temperature : 1434
# atmospheric_pressure : 2106
# outdoor_humidity : 607
# wind_speed : 168
# visibility_index : 376
# dew_point : 1145
# random_variable1 : 15591
# random_variable2 : 15619

# %% [markdown]
# # Checking the DataTypes of each column in the DataFrame

# %%
df.dtypes
# Out:
# timestamp                        object
# equipment_energy_consumption     object
# lighting_energy                  object
# zone1_temperature                object
# zone1_humidity                   object
# zone2_temperature                object
# zone2_humidity                  float64
# zone3_temperature               float64
# zone3_humidity                  float64
# zone4_temperature               float64
# zone4_humidity                  float64
# zone5_temperature               float64
# zone5_humidity                  float64
# zone6_temperature               float64
# zone6_humidity                  float64
# zone7_temperature               float64
# zone7_humidity                  float64
# zone8_temperature               float64
# zone8_humidity                  float64
# zone9_temperature               float64
# zone9_humidity                  float64
# outdoor_temperature             float64
# atmospheric_pressure            float64
# ...

# %% [markdown]
# # Changing the timestamp to date time

# %%
df["timestamp"]= pd.to_datetime(df["timestamp"],format="%Y%m%d",errors="coerce").dt.date

# %% [markdown]
# # Splitting the column into separate columns

# %%
df["year"]= df["timestamp"].dt.year
df["month"]= df["timestamp"].dt.month
df["day"]= df["timestamp"].dt.day
df.head(5)
# Out:
#   timestamp equipment_energy_consumption     lighting_energy  \
# 0       NaT                         60.0  -77.78778596503064
# 1       NaT                         60.0                30.0
# 2       NaT                         50.0                30.0
# 3       NaT                         50.0                40.0
# 4       NaT                         60.0                40.0
#
#    zone1_temperature     zone1_humidity zone2_temperature  zone2_humidity  \
# 0  33.74660933896648  47.59666666666671              19.2       44.790000
# 1              19.89  46.69333333333329              19.2       44.722500
# 2              19.89               46.3              19.2       44.626667
# 3  33.74660933896648   46.0666666666667              19.2       44.590000
# 4              19.89  46.33333333333329              19.2       44.530000
#
#    zone3_temperature  zone3_humidity  zone4_temperature  ...  \
# 0              19.79             NaN          19.000000  ...
# ...

# %% [markdown]
# # Dropping the timestamp column since the column displays NaT-Not a Time

# %%
df.drop(columns=["timestamp"],inplace=True)

# %%
df.drop(columns=["year"],inplace=True)
df.drop(columns=["month"],inplace=True)
df.drop(columns=["day"],inplace=True)

# %% [markdown]
# # Converting the Datatypes from object to float to standardize across all columns

# %%
df["equipment_energy_consumption"]= pd.to_numeric(df["equipment_energy_consumption"],errors="coerce")
df["lighting_energy"]= pd.to_numeric(df["lighting_energy"],errors="coerce")
df["zone1_temperature"]= pd.to_numeric(df["zone1_temperature"],errors="coerce")
df["zone1_humidity"]= pd.to_numeric(df["zone1_humidity"],errors="coerce")
df["zone2_temperature"]= pd.to_numeric(df["zone2_temperature"],errors="coerce")

# %% [markdown]
# # Verifying the datatypes

# %%
df.dtypes
# Out:
# equipment_energy_consumption    float64
# lighting_energy                 float64
# zone1_temperature               float64
# zone1_humidity                  float64
# zone2_temperature               float64
# zone2_humidity                  float64
# zone3_temperature               float64
# zone3_humidity                  float64
# zone4_temperature               float64
# zone4_humidity                  float64
# zone5_temperature               float64
# zone5_humidity                  float64
# zone6_temperature               float64
# zone6_humidity                  float64
# zone7_temperature               float64
# zone7_humidity                  float64
# zone8_temperature               float64
# zone8_humidity                  float64
# zone9_temperature               float64
# zone9_humidity                  float64
# outdoor_temperature             float64
# atmospheric_pressure            float64
# outdoor_humidity                float64
# ...

# %% [markdown]
# # Checking the Statistical Summary of the dataset

# %%
df.describe().T
# Out:
#                                 count        mean         std          min  \
# equipment_energy_consumption  15945.0   95.810413  182.753554 -1139.985693
# lighting_energy               15993.0    3.938101   14.580575   -86.002966
# zone1_temperature             15908.0   21.249414    2.165618     8.726818
# zone1_humidity                15969.0   39.046066    9.952521   -46.660000
# zone2_temperature             15934.0   19.793113    2.943771     2.988199
# zone2_humidity                15990.0   39.494553   10.129513   -77.265503
# zone3_temperature             16055.0   21.665733    2.594309     6.543921
# zone3_humidity                15979.0   38.201314   10.144388   -71.406273
# zone4_temperature             16041.0   20.239922    2.783050     4.613485
# zone4_humidity                16076.0   37.945608   10.769813   -81.446225
# zone5_temperature             16019.0   19.052613    2.346158     5.921094
# ...

# %%
df['zone1_humidity']
# Out:
# 0        47.596667
# 1        46.693333
# 2        46.300000
# 3        46.066667
# 4        46.333333
#            ...
# 16852    38.723333
# 16853    39.626667
# 16854    37.590000
# 16855    39.360000
# 16856    43.863333
# Name: zone1_humidity, Length: 16857, dtype: float64

# %%
df['zone5_humidity'].min()
# Out:
# -141.64014283448853

# %% [markdown]
# # Logically "Equipment_energy_consumption, Lightning_energy, Humidity, Wind_Speed and Visibility_index cannot have negative values, So replacing with NULL values. But "Temperature and Dew_point" can have negative values.

# %% [markdown]
# # The columns below has negative values, So replacing with NULL values

# %%
import numpy as np
df["equipment_energy_consumption"]= df["equipment_energy_consumption"].apply(lambda x: np.nan if x<=0 else x)
df["lighting_energy"]= df["lighting_energy"].apply(lambda x: np.nan if x<=0 else x)
df["zone1_humidity"]= df["zone1_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone2_humidity"]= df["zone2_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone3_humidity"]= df["zone3_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone4_humidity"]= df["zone4_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone5_humidity"]= df["zone5_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone6_humidity"]= df["zone6_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone7_humidity"]= df["zone7_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone8_humidity"]= df["zone8_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["zone9_humidity"]= df["zone9_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["outdoor_humidity"]= df["outdoor_humidity"].apply(lambda x: np.nan if x<=0 else x)
df["wind_speed"]= df["wind_speed"].apply(lambda x: np.nan if x<=0 else x)
df["visibility_index"]= df["visibility_index"].apply(lambda x: np.nan if x<=0 else x)

# %% [markdown]
# # Since most of the columns contain negative values, I converted them into null values. So i am using two random variable column only to improve the model's interpretability

# %%
df["random_variable1"]= df["random_variable1"].apply(lambda x: np.nan if x<=0 else x)
df["random_variable2"]= df["random_variable2"].apply(lambda x: np.nan if x<=0 else x)

# %% [markdown]
# # Checking the number of unique values in all the columns

# %%
df.nunique()
# Out:
# equipment_energy_consumption       93
# lighting_energy                     8
# zone1_temperature                 429
# zone1_humidity                   2038
# zone2_temperature                 834
# zone2_humidity                   2036
# zone3_temperature                 862
# zone3_humidity                   1844
# zone4_temperature                 923
# zone4_humidity                   2313
# zone5_temperature                1633
# zone5_humidity                   6150
# zone6_temperature                3144
# zone6_humidity                   8230
# zone7_temperature                1427
# zone7_humidity                   4775
# zone8_temperature                1672
# zone8_humidity                   5241
# zone9_temperature                 514
# zone9_humidity                   2230
# outdoor_temperature              1434
# atmospheric_pressure             2106
# outdoor_humidity                  503
# wind_speed                        166
# visibility_index                  375
# ...

# %% [markdown]
# # Checking for the NULL values

# %%
df.isnull().sum()
# Out:
# equipment_energy_consumption     1226
# lighting_energy                 12896
# zone1_temperature                 949
# zone1_humidity                   1040
# zone2_temperature                 923
# zone2_humidity                   1011
# zone3_temperature                 802
# zone3_humidity                   1065
# zone4_temperature                 816
# zone4_humidity                   1121
# zone5_temperature                 838
# zone5_humidity                   1102
# zone6_temperature                 848
# zone6_humidity                   1150
# zone7_temperature                 794
# zone7_humidity                   1156
# zone8_temperature                 848
# zone8_humidity                   1101
# zone9_temperature                 773
# zone9_humidity                   1066
# outdoor_temperature               806
# atmospheric_pressure              842
# outdoor_humidity                 1109
# wind_speed                       1002
# visibility_index                  997
# ...

# %% [markdown]
# # The below columns contains null values, hence im filling the columns with "MEDIAN" as the data is skewed and contains outliers. The median is robust to outliers and provides a better central value in such cases.

# %%
df["equipment_energy_consumption"].fillna(df["equipment_energy_consumption"].median(),inplace=True)
df["lighting_energy"].fillna(df["lighting_energy"].median(),inplace=True)
df["zone1_temperature"].fillna(df["zone1_temperature"].median(),inplace=True)
df["zone1_humidity"].fillna(df["zone1_humidity"].median(),inplace=True)
df["zone2_temperature"].fillna(df["zone2_temperature"].median(),inplace=True)
df["zone2_humidity"].fillna(df["zone2_humidity"].median(),inplace=True)
df["zone3_temperature"].fillna(df["zone3_temperature"].median(),inplace=True)
df["zone3_humidity"].fillna(df["zone3_humidity"].median(),inplace=True)
df["zone4_temperature"].fillna(df["zone4_temperature"].median(),inplace=True)
df["zone4_humidity"].fillna(df["zone4_humidity"].median(),inplace=True)
df["zone5_temperature"].fillna(df["zone5_temperature"].median(),inplace=True)
df["zone5_humidity"].fillna(df["zone5_humidity"].median(),inplace=True)
df["zone6_temperature"].fillna(df["zone6_temperature"].median(),inplace=True)
df["zone6_humidity"].fillna(df["zone6_humidity"].median(),inplace=True)
df["zone7_temperature"].fillna(df["zone7_temperature"].median(),inplace=True)
df["zone7_humidity"].fillna(df["zone7_humidity"].median(),inplace=True)
df["zone8_temperature"].fillna(df["zone8_temperature"].median(),inplace=True)
df["zone8_humidity"].fillna(df["zone8_humidity"].median(),inplace=True)
df["zone9_temperature"].fillna(df["zone9_temperature"].median(),inplace=True)
df["zone9_humidity"].fillna(df["zone9_humidity"].median(),inplace=True)
df["outdoor_temperature"].fillna(df["outdoor_temperature"].median(),inplace=True)
df["atmospheric_pressure"].fillna(df["atmospheric_pressure"].median(),inplace=True)
df["outdoor_humidity"].fillna(df["outdoor_humidity"].median(),inplace=True)
df["wind_speed"].fillna(df["wind_speed"].median(),inplace=True)
df["visibility_index"].fillna(df["visibility_index"].median(),inplace=True)
df["dew_point"].fillna(df["dew_point"].median(),inplace=True)
df["random_variable1"].fillna(df["random_variable1"].median(),inplace=True)
df["random_variable2"].fillna(df["random_variable2"].median(),inplace=True)

# %% [markdown]
# # Checking for the null values

# %%
df.isnull().sum()
# Out:
# equipment_energy_consumption    0
# lighting_energy                 0
# zone1_temperature               0
# zone1_humidity                  0
# zone2_temperature               0
# zone2_humidity                  0
# zone3_temperature               0
# zone3_humidity                  0
# zone4_temperature               0
# zone4_humidity                  0
# zone5_temperature               0
# zone5_humidity                  0
# zone6_temperature               0
# zone6_humidity                  0
# zone7_temperature               0
# zone7_humidity                  0
# zone8_temperature               0
# zone8_humidity                  0
# zone9_temperature               0
# zone9_humidity                  0
# outdoor_temperature             0
# atmospheric_pressure            0
# outdoor_humidity                0
# wind_speed                      0
# visibility_index                0
# dew_point                       0
# random_variable1                0
# ...

# %%
df
# Out:
#        equipment_energy_consumption  lighting_energy  zone1_temperature  \
# 0                         60.000000        20.000000          33.746609
# 1                         60.000000        30.000000          19.890000
# 2                         50.000000        30.000000          19.890000
# 3                         50.000000        40.000000          33.746609
# 4                         60.000000        40.000000          19.890000
# ...                             ...              ...                ...
# 16852                   1139.985693        20.000000          22.100000
# 16853                     50.000000        86.002966          21.290000
# 16854                     50.000000        20.000000          21.390000
# 16855                     80.000000        20.000000          22.500000
# 16856                     30.000000        20.000000          20.066667
#
#        zone1_humidity  zone2_temperature  zone2_humidity  zone3_temperature  \
# ...

# %% [markdown]
# # Checking for the statistical summary again to verify that datas are not skewed.

# %%
df.describe().T
# Out:
#                                 count        mean         std         min  \
# equipment_energy_consumption  16857.0  105.051173  143.676732   10.000000
# lighting_energy               16857.0   19.918639    7.729875   10.000000
# zone1_temperature             16857.0   21.253576    2.103842    8.726818
# zone1_humidity                16857.0   39.769547    6.121657    3.348060
# zone2_temperature             16857.0   19.782540    2.862376    2.988199
# zone2_humidity                16857.0   40.226446    6.516192    3.193842
# zone3_temperature             16857.0   21.670575    2.531931    6.543921
# zone3_humidity                16857.0   39.082150    5.322892    6.902515
# zone4_temperature             16857.0   20.242346    2.714872    4.613485
# zone4_humidity                16857.0   39.121109    6.026357   27.660000
# zone5_temperature             16857.0   19.052483    2.287095    5.921094
# zone5_humidity                16857.0   51.924273   12.738615   35.363333
# ...

# %% [markdown]
# # Verifying Skewness using a bar plot and outliers using a box plot

# %%
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

def plot(df,column):
    #histogram plot
    plt.subplot(1,3,2)
    sns.histplot(df, x= column, kde= True, bins=30,color="salmon")
    plt.title("histogram plot for"+" "+column)
    plt.show()

    #boxplot
    plt.subplot(1,3,3)
    sns.boxplot(df, x=column)
    plt.title("Box plot for"+" "+column)
    plt.show()

# %%
skewed_columns=['lighting_energy', 'equipment_energy_consumption', 'zone1_temperature', 'zone1_humidity', 'zone2_temperature', 'zone2_humidity',
                'zone3_temperature', 'zone3_humidity', 'zone4_temperature', 'zone4_humidity', 'zone5_temperature', 'zone5_humidity',
                'zone6_temperature', 'zone6_humidity', 'zone7_temperature', 'zone7_humidity', 'zone8_temperature', 'zone8_humidity',
                'zone9_temperature', 'zone9_humidity', 'outdoor_temperature', 'atmospheric_pressure', 'outdoor_humidity', 'wind_speed', 
                'visibility_index', 'dew_point', 'random_variable1', 'random_variable2']

# %%
for i in skewed_columns:
    plot(df,i)

# %% [markdown]
# # The below columns contains outliers, so treating with IQR method

# %%
def outlier(df,column):
  q1= df[column].quantile(0.25)
  q3= df[column].quantile(0.75)

  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df[column]= df[column].clip(lower_threshold, upper_threshold)

# %%
outlier_columns= ['lighting_energy', 'equipment_energy_consumption', 'random_variable1', 'random_variable2']
for i in outlier_columns:
  outlier(df,i)

# %%
for i in outlier_columns:
  plot(df,i)

# %% [markdown]
# # Checking for the correlation across all the columns

# %%
#Checking the correlation with using the heatmap

corr= df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot= True, fmt="0.2f")
plt.show()

# %% [markdown]
# # Saving the DataSet after done with the Data Preprocessing, EDA and Feature Engineering

# %%
df.to_csv("new_data.csv",index= False)

# %%
new_df = pd.read_csv("new_data.csv")
new_df
# Out:
#        equipment_energy_consumption  lighting_energy  zone1_temperature  \
# 0                              60.0             20.0          33.746609
# 1                              60.0             20.0          19.890000
# 2                              50.0             20.0          19.890000
# 3                              50.0             20.0          33.746609
# 4                              60.0             20.0          19.890000
# ...                             ...              ...                ...
# 16852                         150.0             20.0          22.100000
# 16853                          50.0             20.0          21.290000
# 16854                          50.0             20.0          21.390000
# 16855                          80.0             20.0          22.500000
# 16856                          30.0             20.0          20.066667
#
#        zone1_humidity  zone2_temperature  zone2_humidity  zone3_temperature  \
# ...

# %% [markdown]
# # MODEL DEVELOPMENT AND TRAINING

# %%
# importing the model

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # Finding which algorithm best suits the problem

# %%
# Train Test Split for model selection
def select_model(df, algorithm):
    # x, y spliting
    x= df.drop(columns=["equipment_energy_consumption"])
    y= df["equipment_energy_consumption"]

    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

    model= algorithm().fit(X_train,y_train)
    y_pred_train= model.predict(X_train)
    y_pred_test= model.predict(X_test)
    
    #Checking the accuracy score
    train_mse= mean_squared_error(y_train, y_pred_train)
    train_rmse= np.sqrt(train_mse)
    train_mae= mean_absolute_error(y_train, y_pred_train)
    train_r2= r2_score(y_train, y_pred_train)

    test_mse= mean_squared_error(y_test, y_pred_test)
    test_rmse= np.sqrt(test_mse)
    test_mae= mean_absolute_error(y_test, y_pred_test)
    test_r2= r2_score(y_test, y_pred_test)

    metrics_train={"Data": "Train Data",
        "Name":algorithm.__name__,
        "R2_score":train_r2,
        "Mean_squared_error":train_mse,
        "Root_mean_squared_error":train_rmse,
        "Mean_absolute_error":train_mae
        }

    metrics_test={"Data": "Test Data",
           "Name":algorithm.__name__,
           "R2_score":test_r2,
           "Mean_squared_error":test_mse,
           "Root_mean_squared_error":test_rmse,
           "Mean_absolute_error":test_mae
              }

    print(metrics_train)
    print(metrics_test)
    print("")

# %%
select_model(new_df, DecisionTreeRegressor)
select_model(new_df, RandomForestRegressor)
select_model(new_df, AdaBoostRegressor)
select_model(new_df, ExtraTreesRegressor)
select_model(new_df, GradientBoostingRegressor)
select_model(new_df, XGBRegressor)
# Out:
# {'Data': 'Train Data', 'Name': 'DecisionTreeRegressor', 'R2_score': 1.0, 'Mean_squared_error': 0.0, 'Root_mean_squared_error': 0.0, 'Mean_absolute_error': 0.0}
# {'Data': 'Test Data', 'Name': 'DecisionTreeRegressor', 'R2_score': -0.05586796341853706, 'Mean_squared_error': 1413.226571767497, 'Root_mean_squared_error': 37.59290587022367, 'Mean_absolute_error': 24.54329774614472}
#
# {'Data': 'Train Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.9335715479429822, 'Mean_squared_error': 90.69173822766035, 'Root_mean_squared_error': 9.523221000673058, 'Mean_absolute_error': 6.82437523173897}
# {'Data': 'Test Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.516482747997093, 'Mean_squared_error': 647.1637099644128, 'Root_mean_squared_error': 25.439412531825745, 'Mean_absolute_error': 18.427431791221828}
#
# ...

# %% [markdown]
# # I am choosing RANDOM FOREST as a best algorithm for this problem as its R2 value close to 1 shows MODEL FIT QUALITY  and its MSE and MAE shows less error and it can penalize large mistakes compared to other models

# %%
# Importing necessary packages

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # MODEL EVALUATION AND TESTING

# %% [markdown]
# # Random Forest algorithm has good interpretability and it detect the unseen data without overfitting. So i chose random Forest for this problem

# %%
#x,y spliting
x= new_df.drop(columns=["equipment_energy_consumption"])
y= new_df["equipment_energy_consumption"]

X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

model_1= RandomForestRegressor().fit(X_train,y_train)
y_pred= model_1.predict(X_test)

test_mse= mean_squared_error(y_test, y_pred)
test_rmse= np.sqrt(test_mse)
test_mae= mean_absolute_error(y_test, y_pred)
test_r2= r2_score(y_test, y_pred)

metrics_test={"Data": "Test Data",
        "Name":RandomForestRegressor.__name__,
        "R2_score":test_r2,
        "Mean_squared_error":test_mse,
        "Root_mean_squared_error":test_rmse,
        "Mean_absolute_error":test_mae
            }

print(metrics_test)
# Out:
# {'Data': 'Test Data', 'Name': 'RandomForestRegressor', 'R2_score': 0.5133541359321201, 'Mean_squared_error': 651.3512010676156, 'Root_mean_squared_error': 25.521583043918252, 'Mean_absolute_error': 18.476482799525503}

# %% [markdown]
# # RESULTS AND INSIGHTS
#
# # 1. DATA SUMMARY AND PREPROCESSING:
# a) The dataset contains sensor measurements, environmental readings from multiple zones within the factory, external weather conditions, and energy consumption metrics. It has 16857 rows × 29 columns and the primary target variable is equipment_energy_consumption, which represents the energy used by manufacturing equipment in Wh (watt-hours).
#
# b) The missing values of the entire dataset was totally 15% and it contained negative values. So I converted all the negative values to null and handled using MEDIAN imputation.
#
# c) Outliers detected in three columns which is treated via IQR method.
#
# d) Almost most of the data are related to temperature and humidity so each column positively correlates with other.
#
# # 2. MODEL SELECTION AND DEVELOPMENT:
# a) The various machine learning models that are tested on the dataset are DecisionTree Regressor, RandomForest Regressor, Adaboost Regressor, XGB Regressor, and ExtraTrees Regressor.
#
# b) I am choosing RANDOM FOREST as the best algorithm for this problem as its R2 value close to 1 shows MODEL FIT QUALITY its MSE and MAE show less error and it can penalize large mistakes compared to other models
#
# # 3. MODEL EVALUATION:
# a) The evaluation metrics that are tested are MSE-Mean Squared Error, RMSE-Root Mean Squared Error, MAE-Mean Absolute Error, and R2 score.
#
# b) The metrics are tested on different algorithms, showing various levels of accuracy in each metric. The RANDOMFORESt algorithm shows that the model fits well with data represented using an R2 score, and the MSE and MAE with less error show that the model has good interpretability.
#
# # 4. RESULTS:
# # The RandomForestRegressor was evaluated on the test data.
# a)
# R² Score: 0.:51
# The model explains approximately 51% of the variance in equipment energy consumption on unseen data. This indicates a moderate level of predictive po. T: the model captures more than half of the underlying patterns, but there is still room for improvementb) .
#
# Mean Squared Error (MSE): 6: 51.35
# On average, the squared difference between the predicted and actual energy consumption values is 651.35 units². MSE penalizes larger errors more heavc) ily.
#
# Root Mean Squared Error (RMSE: ): 25.52
# The typical prediction error is about 25.52 units. RMSE is in the same units as the target variable, making it easy to interpret as the average magnitude of prediction d) errors.
#
# Mean Absolute Error (: MAE): 18.48
# On average, the model’s predictions are off by about 18.48 units from the actual values. MAE is less sensitive to outlier
#
# # 5. INSIGHTS:
# a) The moderate R² suggests that while the model captures key drivers of energy usage, there are additional factors or complexities not fully accounted for-such as external influences (weather, operational changes) or unmeasured variables.
# b)
# The relatively low RMSE and MAE values indicate that most predictions are close to actual values, with only a few larger errors.c)
#
# Stakeholders can use this model for planning and operational decisions, but should be aware of its limitations and consider further refinement for critical applicati
#
# # In summary:
# The RandomForestRegressor offers moderate predictive performance for equipment energy consumption, making it useful for general forecasting and operational insights, while highlighting opportunities for furthr model enhancement.ons.s than RMSE.
